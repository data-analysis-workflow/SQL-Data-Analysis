# %% [markdown]
# ![data-analysis-presentation.test.png](attachment:data-analysis-presentation.test.png)

# %% [markdown]
# ![slide 2.png](<attachment:slide 2.png>)

# %% [markdown]
# ![slide 3.png](<attachment:slide 3.png>)
